# %% [markdown]
# ![01.png](attachment:01.png)

# %%
import numpy as np

# %%
# matrix A
A = np.matrix([[0,1,2],[3,4,5],[6,7,8]])
a = np.matrix([-1,1,-2])
result1 = A*(a.transpose())
result1
# Out:
# matrix([[ -3],
#         [ -9],
#         [-15]])

# %%
np.dot(A,a.transpose())
# Out:
# matrix([[ -3],
#         [ -9],
#         [-15]])

# %%
# matrix B
B = np.matrix([[0,1,2],[3,4,5],[6,7,8]])
b = np.matrix([[-1,0],[1,1],[-2,2]])
result2 = B*b
result2
# Out:
# matrix([[ -3,   5],
#         [ -9,  14],
#         [-15,  23]])

# %% [markdown]
# A

# %%
print(np.dot(B,b))
# Out:
# [[ -3   5]
#  [ -9  14]
#  [-15  23]]

# %% [markdown]
# ![02.png](attachment:02.png)

# %% [markdown]
# <b>Using handwrittng

# %% [markdown]
# ![a.png](attachment:a.png)

# %% [markdown]
# ![b.png](attachment:b.png)

# %% [markdown]
# <b>Code

# %%
# question a
a = np.identity(3)
print(a)
verify1 = np.dot(a[:,0],a[:,1])
verify2 = np.dot(a[:,0],a[:,2])
verify3 = np.dot(a[:,1],a[:,2])
print('\n')
verify = np.matrix([[verify1],[verify2],[verify3]])
print(verify)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
#
#
# [[0.]
#  [0.]
#  [0.]]

# %%
# question b
a1 = np.matrix([[1],[0],[0]])
print(a1)
print('the norm of a1 is :',np.linalg.norm(a1,ord=1),'\n')

a2 = np.matrix([[0],[1],[0]])
print(a2)
print('the norm of a2 :',np.linalg.norm(a2,ord=1),'\n')

a3 = np.matrix([[0],[0],[1]])
print(a3)
print('the norm of a3 : ',np.linalg.norm(a3,ord=1))
# Out:
# [[1]
#  [0]
#  [0]]
# the norm of a1 is : 1.0
#
# [[0]
#  [1]
#  [0]]
# the norm of a2 : 1.0
#
# [[0]
#  [0]
#  [1]]
# the norm of a3 :  1.0

# %% [markdown]
# ![03.png](attachment:03.png)

# %%
k = np.matrix([[2/3,1/3,2/3],
               [-2/3,2/3,1/3],
               [1/3,2/3,-2/3]])
print(k)
# Out:
# [[ 0.66666667  0.33333333  0.66666667]
#  [-0.66666667  0.66666667  0.33333333]
#  [ 0.33333333  0.66666667 -0.66666667]]

# %%
test1 = np.dot(k[0,:],k[:,1])
test2 = np.dot(k[0,:],k[:,2])
test3 = np.dot(k[1,:],k[:,2])
print(test1)
print(test2)
print(test3)
# Out:
# [[0.88888889]]
# [[0.11111111]]
# [[-0.44444444]]

# %%
test = np.concatenate([test1,test2,test3]) 
test
# Out:
# matrix([[ 0.88888889],
#         [ 0.11111111],
#         [-0.44444444]])

# %% [markdown]
# ![04.png](attachment:04.png)

# %%
# a.) apply the identity matrix I3 to the vector u
u = np.matrix([2,5,-3])
u2 = np.matrix([0,-4,6])
I = np.identity(3)

# %%
result = np.matmul(u,I)
result
# Out:
# matrix([[ 2.,  5., -3.]])

# %%
# b. apply the matrix B to the vector u.
B = np.matrix([[2,0,-1],[-2,3,1],[0,4,-1]])
result2 = np.dot(u,B)
result2
# Out:
# matrix([[-6,  3,  6]])

# %%
# c. Concatenate u and u2 to form U then apply U with B
U = np.matrix([[2,5,-3],[0,-4,6]])
result3 = np.matmul(U,B)
result3
# Out:
# matrix([[ -6,   3,   6],
#         [  8,  12, -10]])

# %%
U = np.concatenate([u,u2])
U
# Out:
# matrix([[ 2,  5, -3],
#         [ 0, -4,  6]])

# %%
result3 = np.dot(U,B)
result3
# Out:
# matrix([[ -6,   3,   6],
#         [  8,  12, -10]])

# %% [markdown]
# # <p style = 'text-align:center'><b><font color = yellow>The End
