# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Logistics Regression : Classification

# %% [markdown]
# `Logistics regression is used to make classification which the target variable is in form of binary 0 and 1 or just yes or no.`

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np 
import matplotlib.pyplot as plt 
# from lab_utils_common import dic,plot_data
# from plt_one_addpt_onclick import plt_one_addpt_onclick
# plt.style.use('./deeplearning.mpstyle')

# %%
x_train = np.array([0,1,2,3,4,5])
y_train = np.array([0,0,0,1,1,1])
x_train2 = np.array([[0.5,1.5],[1,1],[1.5,0.5],[3,0.5],[2,2],[1,2.5]])
y_train2 = np.array([0,0,0,1,1,1])

# %%
pos = y_train == 1 
neg = y_train == 0 

fig,ax = plt.subplots(1,2,figsize=(8,3))
# plot 1, single variable 
ax[0].scatterplot(x_train[pos],y_train[pos],marker='x',s=80,c='red',label='y=1')
ax[0].scatterplot(x_train[neg],y_train[neg],marker='o',s=100,c='blue',label='y=1',facecolors='None',edgecolors=dlc['dlblue'])
